# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# %matplotlib inline

# %%
DA=pd.read_csv('Dataset A.csv')

# %%
DA
# Out:
#                   Name                       Email ID  Phone Number  \
# 0    Michael Stefenson      mstephenson@fernandez.com    3028039388
# 1        Hershal Stark              hduke@hotmail.com    9089646263
# 2           Allen Paul               pallen@yahoo.com    7071678287
# 3      Rebecca Ganguly        riverarebecca@gmail.com    3343675411
# 4        Stefen Potter  mstephens@davidson-herman.com    3760942236
# ..                 ...                            ...           ...
# 495      Jessica Lewis   lewisjessica@craig-evans.com    2938951583
# 496       Katrina Kaif            katrina56@gmail.com    1810163196
# 497         Dale Stein             dale88@hotmail.com    2751936173
# 498  Christofer Wilson            cwilson@hotmail.com    5175585593
# 499      Hannah Wilson      hannahwilson@davidson.com    8332497042
#
#      Average Time on App (Minutes/Day)  Total Purchase from App (Rupees/year)  \
# ...

# %%
DA.describe()
# Out:
#        Phone Number  Average Time on App (Minutes/Day)  \
# count  5.000000e+02                         500.000000
# mean   5.469654e+09                          24.929437
# std    2.612551e+09                           2.909053
# min    1.053311e+09                          20.008966
# 25%    3.208662e+09                          22.240235
# 50%    5.354163e+09                          24.897305
# 75%    7.768053e+09                          27.519510
# max    9.969679e+09                          29.997169
#
#        Total Purchase from App (Rupees/year)  \
# count                             500.000000
# mean                             4756.140000
# std                              2804.249391
# min                               102.000000
# 25%                              2403.750000
# 50%                              4644.500000
# 75%                              7159.000000
# max                              9935.000000
#
#        Average Time on Website (Minutes/Day)  \
# ...

# %%
sns.jointplot(x='Average Time on App (Minutes/Day)',y='Total Purchase of each customer (Rupees/year)',data=DA,kind='scatter')

# %%
sns.jointplot(x='Average Time on Website (Minutes/Day)',y='Total Purchase of each customer (Rupees/year)',data=DA,kind='scatter')

# %%
plt.scatter(DA['Average Time on App (Minutes/Day)'],DA['Total Purchase of each customer (Rupees/year)'])

# %%
plt.scatter(DA['Average Time on Website (Minutes/Day)'],DA['Total Purchase of each customer (Rupees/year)'])

# %%
sns.lmplot(data=DA, x='Average Time on Website (Minutes/Day)', y='Total Purchase of each customer (Rupees/year)')

# %%
sns.lmplot(data=DA, x='Average Time on App (Minutes/Day)', y='Total Purchase of each customer (Rupees/year)')

# %%
sns.jointplot(x='Average Time on App (Minutes/Day)', y='Total Purchase of each customer (Rupees/year)',data=DA,color='red',kind='kde')

# %%
sns.jointplot(x='Average Time on Website (Minutes/Day)', y='Total Purchase of each customer (Rupees/year)',data=DA,color='red',kind='kde')

# %%
sns.distplot(DA['Average Time on Website (Minutes/Day)'])

# %%
sns.distplot(DA['Average Time on App (Minutes/Day)'])

# %%
sns.distplot(DA['Total Purchase of each customer (Rupees/year)'])

# %%
from sklearn.model_selection import train_test_split

# %%
X=DA[['Average Time on App (Minutes/Day)','Average Time on Website (Minutes/Day)']]
y=DA['Total Purchase of each customer (Rupees/year)']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=25)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions=lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
coeff_df=pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                                        Coefficient
# Average Time on App (Minutes/Day)        20.213146
# Average Time on Website (Minutes/Day)    59.398727
